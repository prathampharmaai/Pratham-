# %% [markdown]
# <a href="https://colab.research.google.com/github/prathampharmaai/Pratham-/blob/main/Rdkit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
from rdkit import Chem

m = Chem.MolFromSmiles('c1ccccc1')
m

# %%
# !pip install rdkit
from rdkit import Chem

mol = Chem.MolFromSmiles('cccc')
mol
# Out:
# ...
# [05:03:30] non-ring atom 0 marked aromatic

# %%
# !pip install rdkit
from rdkit import Chem
from rdkit.Chem import Draw
smiles_list = ['CC(=O)Oc1ccccc1C(=O)O', # Aspirin
'CC(=O)Nc1ccc(O)cc1', # Paracetamol
'Cn1cnc2c1c(=O)n(C)c(=O)n2C', # Caffeine
'CC(C)Cc1ccc(cc1)C(C)C(=O)O'] # Ibuprofen
mol_list =[]

for smiles in smiles_list:
  mol = Chem.MolFromSmiles(smiles)
  mol_list.append(mol)

img = Draw.MolsToGridImage(mol_list)
img
