# %% [markdown]
# <a href="https://colab.research.google.com/github/prathampharmaai/Pratham-/blob/main/pandas_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/dataprofessor/data/master/delaney.csv -O solubility.csv

import pandas as pd
df = pd.read_csv('solubility.csv')
df.head()
# Out:
# --2026-03-14 04:06:34--  https://raw.githubusercontent.com/dataprofessor/data/master/delaney.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58889 (58K) [text/plain]
# Saving to: ‘solubility.csv’
#
# solubility.csv      100%[===================>]  57.51K  --.-KB/s    in 0.02s
#
# 2026-03-14 04:06:35 (3.33 MB/s) - ‘solubility.csv’ saved [58889/58889]
#                       Compound ID  measured log(solubility:mol/L)  \
# 0       1,1,1,2-Tetrachloroethane                           -2.18
# 1           1,1,1-Trichloroethane                           -2.00
# 2       1,1,2,2-Tetrachloroethane                           -1.74
# 3           1,1,2-Trichloroethane                           -1.48
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 4 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Compound ID                           1144 non-null   object
#  1   measured log(solubility:mol/L)        1144 non-null   float64
#  2   ESOL predicted log(solubility:mol/L)  1144 non-null   float64
#  3   SMILES                                1144 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 35.9+ KB

# %%
df.describe()
# Out:
#        measured log(solubility:mol/L)  ESOL predicted log(solubility:mol/L)
# count                     1144.000000                           1144.000000
# mean                        -3.057997                             -2.994776
# std                          2.096502                              1.686520
# min                        -11.600000                             -9.702000
# 25%                         -4.332250                             -3.962250
# 50%                         -2.870500                             -2.889000
# 75%                         -1.600000                             -1.846750
# max                          1.580000                              1.091000

# %%
df.columns
# Out:
# Index(['Compound ID', 'measured log(solubility:mol/L)',
#        'ESOL predicted log(solubility:mol/L)', 'SMILES'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1144, step=1)

# %%
df.tail()
# Out:
#       Compound ID  measured log(solubility:mol/L)  \
# 1139  vamidothion                           1.144
# 1140  Vinclozolin                          -4.925
# 1141     Warfarin                          -3.893
# 1142     Xipamide                          -3.790
# 1143          XMC                          -2.581
#
#       ESOL predicted log(solubility:mol/L)  \
# 1139                                -1.446
# 1140                                -4.377
# 1141                                -3.913
# 1142                                -3.642
# 1143                                -2.688
#
#                                            SMILES
# 1139                 CNC(=O)C(C)SCCSP(=O)(OC)(OC)
# 1140        CC1(OC(=O)N(C1=O)c2cc(Cl)cc(Cl)c2)C=C
# 1141       CC(=O)CC(c1ccccc1)c3c(O)c2ccccc2oc3=O
# 1142  Cc1cccc(C)c1NC(=O)c2cc(c(Cl)cc2O)S(N)(=O)=O
# 1143                       CNC(=O)Oc1cc(C)cc(C)c1
