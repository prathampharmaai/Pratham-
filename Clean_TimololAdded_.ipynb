# %% [markdown]
# <a href="https://colab.research.google.com/github/prathampharmaai/Pratham-/blob/main/Clean_TimololAdded_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/dataprofessor/data/master/delaney.csv -O solubility.csv
import pandas as pd
df=pd.read_csv('solubility.csv')
df.head()
# Out:
# --2026-03-14 13:47:12--  https://raw.githubusercontent.com/dataprofessor/data/master/delaney.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58889 (58K) [text/plain]
# Saving to: ‘solubility.csv’
#
# solubility.csv      100%[===================>]  57.51K  --.-KB/s    in 0.001s
#
# 2026-03-14 13:47:12 (44.3 MB/s) - ‘solubility.csv’ saved [58889/58889]
#                       Compound ID  measured log(solubility:mol/L)  \
# 0       1,1,1,2-Tetrachloroethane                           -2.18
# 1           1,1,1-Trichloroethane                           -2.00
# 2       1,1,2,2-Tetrachloroethane                           -1.74
# 3           1,1,2-Trichloroethane                           -1.48
# ...

# %%
df[df['Compound ID']== "smile's"]
# Out:
# Empty DataFrame
# Columns: [Compound ID, measured log(solubility:mol/L), ESOL predicted log(solubility:mol/L), SMILES]
# Index: []

# %%
df.dropna()
# Out:
#                          Compound ID  measured log(solubility:mol/L)  \
# 0          1,1,1,2-Tetrachloroethane                          -2.180
# 1              1,1,1-Trichloroethane                          -2.000
# 2          1,1,2,2-Tetrachloroethane                          -1.740
# 3              1,1,2-Trichloroethane                          -1.480
# 4     1,1,2-Trichlorotrifluoroethane                          -3.040
# ...                              ...                             ...
# 1139                     vamidothion                           1.144
# 1140                     Vinclozolin                          -4.925
# 1141                        Warfarin                          -3.893
# 1142                        Xipamide                          -3.790
# 1143                             XMC                          -2.581
#
#       ESOL predicted log(solubility:mol/L)  \
# 0                                   -2.794
# 1                                   -2.232
# ...

# %%
 print(df.shape)
# Out:
# (1144, 4)

# %%
df[df['measured log(solubility:mol/L)']<500].head()
# Out:
#                       Compound ID  measured log(solubility:mol/L)  \
# 0       1,1,1,2-Tetrachloroethane                           -2.18
# 1           1,1,1-Trichloroethane                           -2.00
# 2       1,1,2,2-Tetrachloroethane                           -1.74
# 3           1,1,2-Trichloroethane                           -1.48
# 4  1,1,2-Trichlorotrifluoroethane                           -3.04
#
#    ESOL predicted log(solubility:mol/L)               SMILES
# 0                                -2.794       ClCC(Cl)(Cl)Cl
# 1                                -2.232         CC(Cl)(Cl)Cl
# 2                                -2.549       ClC(Cl)C(Cl)Cl
# 3                                -1.961           ClCC(Cl)Cl
# 4                                -3.077  FC(F)(Cl)C(F)(Cl)Cl

# %%
df[df['Compound ID'].str.startswith('1')]
# Out:
#                         Compound ID  measured log(solubility:mol/L)  \
# 0         1,1,1,2-Tetrachloroethane                           -2.18
# 1             1,1,1-Trichloroethane                           -2.00
# 2         1,1,2,2-Tetrachloroethane                           -1.74
# 3             1,1,2-Trichloroethane                           -1.48
# 4    1,1,2-Trichlorotrifluoroethane                           -3.04
# ..                              ...                             ...
# 111                      1-Pentene                            -2.68
# 112                       1-Pentyne                           -1.64
# 113                 1-Phenylethanol                           -0.92
# 114                      1-Propanol                            0.62
# 115                  1-Tetradecanol                           -5.84
#
#      ESOL predicted log(solubility:mol/L)               SMILES
# 0                                  -2.794       ClCC(Cl)(Cl)Cl
# ...
