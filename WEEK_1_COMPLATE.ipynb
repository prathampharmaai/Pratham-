# %% [markdown]
# <a href="https://colab.research.google.com/github/prathampharmaai/Pratham-/blob/main/WEEK_1_COMPLATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df1 =pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/master/delaney_solubility_with_descriptors.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/deepchem/deepchem/master/datasets/delaney-processed.csv')
df1.head()
lipnsik = df1[(df1['MolWt']<500)&(df1['MolLogP']<5)]
print(f'Pass Lipinski: {len(lipnsik)} / {len(df1)}')

lipnsik.to_csv('lipinski_drugs.csv', index=False)
df2.to_csv('delaney_smiles.csv', index=False)
# Out:
# Pass Lipinski: 1039 / 1144
